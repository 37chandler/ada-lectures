# %% [markdown]
# ## Gather Follower Descriptions
# We start with a twitter user name (as well as things like twitter credentials) and pull all the followers of that user. We then pull the descriptions of those users and write them to a file for future mining. You can use more than one user in a group.
#
# I wrote some functions for you in the file `twitter_functions.py`. This will need to be in the same folder where you're running this notebook.

# %%
from datetime import datetime
import json
from pprint import pprint

from twitter_functions import * # these are the functions I wrote for you.

# %% [markdown]
# The next cell holds your Twitter authorization credentials. Then it calls a function that initializes your connection to Twitter. I've left my keys in there (slightly perturbed so that they won't actually work) so that you see the form these take).

# %%
from twitter_config import *

#auth =  { "consumer_key": "xks2XTK4gr2PajPio1RBGWsYU",
#          "consumer_secret": "jkjkCjph2vx38uBVbVHLkhzesGVY6ZqEywXd3B0sDeSAWVcDNo",
#          "access_key": "33029025-i1Mm907o7BsKnufMIxjVzByKsuDEhOBb0yV3EAa1E",
#          "access_secret": "jkjkXqAijIwRQMZmW3b7AgpFXU6Ve0RU30fzsbzpfx9uf"
#        }

api = initialize_twitter(auth)

# %% [markdown]
# Now you set the handle (or handles) that represent one group or topic on Twitter. These should be in a list. The output file name (`ofile_name`) is determined based on today's date and the first element in the list. Feel free to modify.

# %%
starting_user = ['GeneralMills','kraftfoods'] # my first group
#starting_user = ['michaelpollan'] # my second group

ofile_name = (datetime.today().strftime("%Y%m%d") + "_" + 
             starting_user[0] + "_" + # Just take the first one if there are multiple
             "followers.txt")

# %%
# We'll now go lookup the full information on your starting user(s). 
starting_user_id = []

# All records will be a dictionary with the twitter ID as the key and 
# a UserRecord as the value. This is a named tuple I created. 
all_records = lookup_users_from_handles(api, starting_user)

# We need the IDs that we're getting followers from in a list. 
for id in all_records : #access the keys, which are ids.
    starting_user_id.append(id)
# Out:
# Start lookup_users_from_ids on 2 handles.
# 20181106-000057: looking up user records for 2 handles.
# 20181106-000057:  users pulled:  2
# total failures: 0

# %%
# How long is it going to take us to pull these followers?
total_followers = 0
for id, rec in all_records.items() :
    total_followers += rec.followers_count
    
print("Ooh, {fol:d} followers. A complete run with no limits run is ".format(fol=total_followers) + 
      "going to take {min:.2f} minutes ({hour:.2f} hours)".format(min=total_followers/5000,
                                                                  hour=total_followers/(60*5000)))
# Out:
# Ooh, 93217 followers. A complete run with no limits run is going to take 18.64 minutes (0.31 hours)

# %%
# Now let's pull all the followers of our starting_user
# the function I wrote allows you to cap the number of followers you pull
# and uses the ID to generate the query.
# 
# Note that this pull is subject to rate limiting. You can make 15 calls per
# 15 minute window and each can return 5000 users. 
followers_of_starting = gather_followers(api,
                                         starting_user_id,
                                         follower_limit=None) # Modify this limit if you need to. 
                                                              # Set it to "None" to get all   

# followers_of_starting will be a dictionary with the key being the id(s) in starting_user_id
# and the value is a list of all the followers.
# Out:
# Pulling followers for 280557152
# Rate limit reached. Sleeping for: 770
# Number pulled: 5000
# Number pulled: 10000
# Number pulled: 15000
# Number pulled: 20000
# Number pulled: 25000
# Rate limit reached. Sleeping for: 898
# Number pulled: 30000
# Number pulled: 35000
# Number pulled: 40000
# Number pulled: 45000
# Number pulled: 50000
# Number pulled: 55000
# Number pulled: 60000
# Number pulled: 65000
# Rate limit reached. Sleeping for: 898
# Number pulled: 70000
# Number pulled: 75000
# Number pulled: 80000
# Number pulled: 85000
# Number pulled: 90000
# Number pulled: 93217

# %%
# And now we'll "hydrate" these user records.
for start_id, list_of_followers in followers_of_starting.items() :
    
    # Using a set here instead of a list so that we pull each ID only once.
    ids_to_hydrate = {id for id in list_of_followers if id not in all_records} 
    
    these_records = lookup_users_from_ids(api,ids=ids_to_hydrate)

    for id, rec in these_records.items() :
        all_records[id] = rec
# Out:
# Start lookup_users_from_ids on 93217 IDs.
# 20181106-004404: looking up user records for 100 IDs.
# 20181106-004405: looking up user records for 100 IDs.
# 20181106-004406: looking up user records for 100 IDs.
# 20181106-004407: looking up user records for 100 IDs.
# 20181106-004409: looking up user records for 100 IDs.
# 20181106-004410: looking up user records for 100 IDs.
# 20181106-004411: looking up user records for 100 IDs.
# 20181106-004412: looking up user records for 100 IDs.
# 20181106-004413: looking up user records for 100 IDs.
# 20181106-004415: looking up user records for 100 IDs.
# 20181106-004416: looking up user records for 100 IDs.
# 20181106-004417: looking up user records for 100 IDs.
# 20181106-004418: looking up user records for 100 IDs.
# 20181106-004420: looking up user records for 100 IDs.
# 20181106-004421: looking up user records for 100 IDs.
# 20181106-004422: looking up user records for 100 IDs.
# 20181106-004423: looking up user records for 100 IDs.
# 20181106-004424: looking up user records for 100 IDs.
# 20181106-004426: looking up user records for 100 IDs.
# 20181106-004427: looking up user records for 100 IDs.
# 20181106-004428: looking up user records for 100 IDs.
# 20181106-004429: looking up user records for 100 IDs.
# 20181106-004430: looking up user records for 100 IDs.
# 20181106-004431: looking up user records for 100 IDs.
# 20181106-004433: looking up user records for 100 IDs.
# 20181106-004434: looking up user records for 100 IDs.
# 20181106-004435: looking up user records for 100 IDs.
# 20181106-004436: looking up user records for 100 IDs.
# 20181106-004437: looking up user records for 100 IDs.
# 20181106-004438: looking up user records for 100 IDs.
# 20181106-004440: looking up user records for 100 IDs.
# 20181106-004441: looking up user records for 100 IDs.
# 20181106-004442: looking up user records for 100 IDs.
# 20181106-004443: looking up user records for 100 IDs.
# 20181106-004444: looking up user records for 100 IDs.
# 20181106-004446: looking up user records for 100 IDs.
# 20181106-004447: looking up user records for 100 IDs.
# 20181106-004448: looking up user records for 100 IDs.
# 20181106-004449: looking up user records for 100 IDs.
# 20181106-004451: looking up user records for 100 IDs.
# 20181106-004452: looking up user records for 100 IDs.
# 20181106-004453: looking up user records for 100 IDs.
# 20181106-004454: looking up user records for 100 IDs.
# 20181106-004455: looking up user records for 100 IDs.
# 20181106-004457: looking up user records for 100 IDs.
# 20181106-004458: looking up user records for 100 IDs.
# 20181106-004459: looking up user records for 100 IDs.
# 20181106-004500: looking up user records for 100 IDs.
# 20181106-004501: looking up user records for 100 IDs.
# 20181106-004503: looking up user records for 100 IDs.
# 20181106-004504: looking up user records for 100 IDs.
# 20181106-004505: looking up user records for 100 IDs.
# 20181106-004506: looking up user records for 100 IDs.
# 20181106-004508: looking up user records for 100 IDs.
# 20181106-004509: looking up user records for 100 IDs.
# 20181106-004510: looking up user records for 100 IDs.
# 20181106-004511: looking up user records for 100 IDs.
# 20181106-004512: looking up user records for 100 IDs.
# 20181106-004514: looking up user records for 100 IDs.
# 20181106-004515: looking up user records for 100 IDs.
# 20181106-004516: looking up user records for 100 IDs.
# 20181106-004517: looking up user records for 100 IDs.
# 20181106-004518: looking up user records for 100 IDs.
# 20181106-004520: looking up user records for 100 IDs.
# 20181106-004521: looking up user records for 100 IDs.
# 20181106-004522: looking up user records for 100 IDs.
# 20181106-004523: looking up user records for 100 IDs.
# 20181106-004524: looking up user records for 100 IDs.
# 20181106-004526: looking up user records for 100 IDs.
# 20181106-004527: looking up user records for 100 IDs.
# 20181106-004528: looking up user records for 100 IDs.
# 20181106-004529: looking up user records for 100 IDs.
# 20181106-004530: looking up user records for 100 IDs.
# 20181106-004532: looking up user records for 100 IDs.
# 20181106-004533: looking up user records for 100 IDs.
# 20181106-004534: looking up user records for 100 IDs.
# 20181106-004535: looking up user records for 100 IDs.
# 20181106-004536: looking up user records for 100 IDs.
# 20181106-004537: looking up user records for 100 IDs.
# 20181106-004539: looking up user records for 100 IDs.
# 20181106-004540: looking up user records for 100 IDs.
# 20181106-004541: looking up user records for 100 IDs.
# 20181106-004542: looking up user records for 100 IDs.
# 20181106-004544: looking up user records for 100 IDs.
# 20181106-004545: looking up user records for 100 IDs.
# 20181106-004546: looking up user records for 100 IDs.
# 20181106-004547: looking up user records for 100 IDs.
# 20181106-004548: looking up user records for 100 IDs.
# 20181106-004550: looking up user records for 100 IDs.
# 20181106-004551: looking up user records for 100 IDs.
# 20181106-004552: looking up user records for 100 IDs.
# 20181106-004553: looking up user records for 100 IDs.
# 20181106-004555: looking up user records for 100 IDs.
# 20181106-004556: looking up user records for 100 IDs.
# 20181106-004557: looking up user records for 100 IDs.
# 20181106-004558: looking up user records for 100 IDs.
# 20181106-004559: looking up user records for 100 IDs.
# 20181106-004601: looking up user records for 100 IDs.
# 20181106-004602: looking up user records for 100 IDs.
# 20181106-004603: looking up user records for 100 IDs.
# 20181106-004605: looking up user records for 100 IDs.
# 20181106-004606: looking up user records for 100 IDs.
# 20181106-004607: looking up user records for 100 IDs.
# 20181106-004608: looking up user records for 100 IDs.
# 20181106-004609: looking up user records for 100 IDs.
# 20181106-004611: looking up user records for 100 IDs.
# 20181106-004612: looking up user records for 100 IDs.
# 20181106-004613: looking up user records for 100 IDs.
# 20181106-004614: looking up user records for 100 IDs.
# 20181106-004615: looking up user records for 100 IDs.
# 20181106-004616: looking up user records for 100 IDs.
# 20181106-004618: looking up user records for 100 IDs.
# 20181106-004619: looking up user records for 100 IDs.
# 20181106-004620: looking up user records for 100 IDs.
# 20181106-004621: looking up user records for 100 IDs.
# 20181106-004622: looking up user records for 100 IDs.
# 20181106-004623: looking up user records for 100 IDs.
# 20181106-004624: looking up user records for 100 IDs.
# 20181106-004626: looking up user records for 100 IDs.
# 20181106-004627: looking up user records for 100 IDs.
# 20181106-004628: looking up user records for 100 IDs.
# 20181106-004629: looking up user records for 100 IDs.
# 20181106-004630: looking up user records for 100 IDs.
# 20181106-004632: looking up user records for 100 IDs.
# 20181106-004633: looking up user records for 100 IDs.
# 20181106-004634: looking up user records for 100 IDs.
# 20181106-004635: looking up user records for 100 IDs.
# 20181106-004636: looking up user records for 100 IDs.
# 20181106-004637: looking up user records for 100 IDs.
# 20181106-004639: looking up user records for 100 IDs.
# 20181106-004640: looking up user records for 100 IDs.
# 20181106-004641: looking up user records for 100 IDs.
# 20181106-004642: looking up user records for 100 IDs.
# 20181106-004643: looking up user records for 100 IDs.
# 20181106-004644: looking up user records for 100 IDs.
# 20181106-004646: looking up user records for 100 IDs.
# 20181106-004647: looking up user records for 100 IDs.
# 20181106-004648: looking up user records for 100 IDs.
# 20181106-004649: looking up user records for 100 IDs.
# 20181106-004650: looking up user records for 100 IDs.
# 20181106-004652: looking up user records for 100 IDs.
# 20181106-004653: looking up user records for 100 IDs.
# 20181106-004654: looking up user records for 100 IDs.
# 20181106-004656: looking up user records for 100 IDs.
# 20181106-004657: looking up user records for 100 IDs.
# 20181106-004658: looking up user records for 100 IDs.
# 20181106-004700: looking up user records for 100 IDs.
# 20181106-004701: looking up user records for 100 IDs.
# 20181106-004703: looking up user records for 100 IDs.
# 20181106-004704: looking up user records for 100 IDs.
# 20181106-004705: looking up user records for 100 IDs.
# 20181106-004706: looking up user records for 100 IDs.
# 20181106-004708: looking up user records for 100 IDs.
# 20181106-004709: looking up user records for 100 IDs.
# 20181106-004710: looking up user records for 100 IDs.
# 20181106-004711: looking up user records for 100 IDs.
# 20181106-004713: looking up user records for 100 IDs.
# 20181106-004714: looking up user records for 100 IDs.
# 20181106-004715: looking up user records for 100 IDs.
# 20181106-004716: looking up user records for 100 IDs.
# 20181106-004717: looking up user records for 100 IDs.
# 20181106-004718: looking up user records for 100 IDs.
# 20181106-004720: looking up user records for 100 IDs.
# 20181106-004721: looking up user records for 100 IDs.
# 20181106-004722: looking up user records for 100 IDs.
# 20181106-004723: looking up user records for 100 IDs.
# 20181106-004724: looking up user records for 100 IDs.
# 20181106-004725: looking up user records for 100 IDs.
# 20181106-004727: looking up user records for 100 IDs.
# 20181106-004728: looking up user records for 100 IDs.
# 20181106-004729: looking up user records for 100 IDs.
# 20181106-004730: looking up user records for 100 IDs.
# 20181106-004731: looking up user records for 100 IDs.
# 20181106-004733: looking up user records for 100 IDs.
# 20181106-004734: looking up user records for 100 IDs.
# 20181106-004735: looking up user records for 100 IDs.
# 20181106-004736: looking up user records for 100 IDs.
# 20181106-004738: looking up user records for 100 IDs.
# 20181106-004739: looking up user records for 100 IDs.
# 20181106-004740: looking up user records for 100 IDs.
# 20181106-004741: looking up user records for 100 IDs.
# 20181106-004742: looking up user records for 100 IDs.
# 20181106-004743: looking up user records for 100 IDs.
# 20181106-004744: looking up user records for 100 IDs.
# 20181106-004746: looking up user records for 100 IDs.
# 20181106-004747: looking up user records for 100 IDs.
# 20181106-004748: looking up user records for 100 IDs.
# 20181106-004749: looking up user records for 100 IDs.
# 20181106-004750: looking up user records for 100 IDs.
# 20181106-004751: looking up user records for 100 IDs.
# 20181106-004752: looking up user records for 100 IDs.
# 20181106-004754: looking up user records for 100 IDs.
# 20181106-004755: looking up user records for 100 IDs.
# 20181106-004756: looking up user records for 100 IDs.
# 20181106-004757: looking up user records for 100 IDs.
# 20181106-004758: looking up user records for 100 IDs.
# 20181106-004759: looking up user records for 100 IDs.
# 20181106-004801: looking up user records for 100 IDs.
# 20181106-004802: looking up user records for 100 IDs.
# 20181106-004803: looking up user records for 100 IDs.
# 20181106-004804: looking up user records for 100 IDs.
# 20181106-004806: looking up user records for 100 IDs.
# 20181106-004807: looking up user records for 100 IDs.
# 20181106-004808: looking up user records for 100 IDs.
# 20181106-004809: looking up user records for 100 IDs.
# 20181106-004810: looking up user records for 100 IDs.
# 20181106-004811: looking up user records for 100 IDs.
# 20181106-004813: looking up user records for 100 IDs.
# 20181106-004814: looking up user records for 100 IDs.
# 20181106-004815: looking up user records for 100 IDs.
# 20181106-004816: looking up user records for 100 IDs.
# 20181106-004817: looking up user records for 100 IDs.
# 20181106-004818: looking up user records for 100 IDs.
# 20181106-004819: looking up user records for 100 IDs.
# 20181106-004821: looking up user records for 100 IDs.
# 20181106-004822: looking up user records for 100 IDs.
# 20181106-004823: looking up user records for 100 IDs.
# 20181106-004825: looking up user records for 100 IDs.
# 20181106-004826: looking up user records for 100 IDs.
# 20181106-004827: looking up user records for 100 IDs.
# 20181106-004828: looking up user records for 100 IDs.
# 20181106-004829: looking up user records for 100 IDs.
# 20181106-004830: looking up user records for 100 IDs.
# 20181106-004831: looking up user records for 100 IDs.
# 20181106-004833: looking up user records for 100 IDs.
# 20181106-004834: looking up user records for 100 IDs.
# 20181106-004835: looking up user records for 100 IDs.
# 20181106-004836: looking up user records for 100 IDs.
# 20181106-004837: looking up user records for 100 IDs.
# 20181106-004839: looking up user records for 100 IDs.
# 20181106-004840: looking up user records for 100 IDs.
# 20181106-004841: looking up user records for 100 IDs.
# 20181106-004842: looking up user records for 100 IDs.
# 20181106-004844: looking up user records for 100 IDs.
# 20181106-004845: looking up user records for 100 IDs.
# 20181106-004846: looking up user records for 100 IDs.
# 20181106-004847: looking up user records for 100 IDs.
# 20181106-004849: looking up user records for 100 IDs.
# 20181106-004850: looking up user records for 100 IDs.
# 20181106-004851: looking up user records for 100 IDs.
# 20181106-004852: looking up user records for 100 IDs.
# 20181106-004854: looking up user records for 100 IDs.
# 20181106-004855: looking up user records for 100 IDs.
# 20181106-004856: looking up user records for 100 IDs.
# 20181106-004857: looking up user records for 100 IDs.
# 20181106-004858: looking up user records for 100 IDs.
# 20181106-004900: looking up user records for 100 IDs.
# 20181106-004901: looking up user records for 100 IDs.
# 20181106-004903: looking up user records for 100 IDs.
# 20181106-004904: looking up user records for 100 IDs.
# 20181106-004905: looking up user records for 100 IDs.
# 20181106-004906: looking up user records for 100 IDs.
# 20181106-004907: looking up user records for 100 IDs.
# 20181106-004909: looking up user records for 100 IDs.
# 20181106-004910: looking up user records for 100 IDs.
# 20181106-004911: looking up user records for 100 IDs.
# 20181106-004912: looking up user records for 100 IDs.
# 20181106-004913: looking up user records for 100 IDs.
# 20181106-004914: looking up user records for 100 IDs.
# 20181106-004915: looking up user records for 100 IDs.
# 20181106-004917: looking up user records for 100 IDs.
# 20181106-004918: looking up user records for 100 IDs.
# 20181106-004919: looking up user records for 100 IDs.
# 20181106-004920: looking up user records for 100 IDs.
# 20181106-004921: looking up user records for 100 IDs.
# 20181106-004923: looking up user records for 100 IDs.
# 20181106-004924: looking up user records for 100 IDs.
# 20181106-004925: looking up user records for 100 IDs.
# 20181106-004926: looking up user records for 100 IDs.
# 20181106-004927: looking up user records for 100 IDs.
# 20181106-004928: looking up user records for 100 IDs.
# 20181106-004930: looking up user records for 100 IDs.
# 20181106-004931: looking up user records for 100 IDs.
# 20181106-004932: looking up user records for 100 IDs.
# 20181106-004933: looking up user records for 100 IDs.
# 20181106-004934: looking up user records for 100 IDs.
# 20181106-004936: looking up user records for 100 IDs.
# 20181106-004937: looking up user records for 100 IDs.
# 20181106-004938: looking up user records for 100 IDs.
# 20181106-004939: looking up user records for 100 IDs.
# 20181106-004941: looking up user records for 100 IDs.
# 20181106-004942: looking up user records for 100 IDs.
# 20181106-004943: looking up user records for 100 IDs.
# 20181106-004944: looking up user records for 100 IDs.
# 20181106-004945: looking up user records for 100 IDs.
# 20181106-004946: looking up user records for 100 IDs.
# 20181106-004948: looking up user records for 100 IDs.
# 20181106-004949: looking up user records for 100 IDs.
# 20181106-004950: looking up user records for 100 IDs.
# 20181106-004952: looking up user records for 100 IDs.
# 20181106-004953: looking up user records for 100 IDs.
# 20181106-004954: looking up user records for 100 IDs.
# 20181106-004955: looking up user records for 100 IDs.
# 20181106-004956: looking up user records for 100 IDs.
# 20181106-004958: looking up user records for 100 IDs.
# 20181106-004959: looking up user records for 100 IDs.
# 20181106-005000: looking up user records for 100 IDs.
# 20181106-005001: looking up user records for 100 IDs.
# 20181106-005003: looking up user records for 100 IDs.
# 20181106-005004: looking up user records for 100 IDs.
# 20181106-005005: looking up user records for 100 IDs.
# 20181106-005006: looking up user records for 100 IDs.
# 20181106-005007: looking up user records for 100 IDs.
# 20181106-005009: looking up user records for 100 IDs.
# 20181106-005010: looking up user records for 100 IDs.
# 20181106-005011: looking up user records for 100 IDs.
# 20181106-005012: looking up user records for 100 IDs.
# 20181106-005013: looking up user records for 100 IDs.
# 20181106-005015: looking up user records for 100 IDs.
# 20181106-005016: looking up user records for 100 IDs.
# 20181106-005017: looking up user records for 100 IDs.
# 20181106-005018: looking up user records for 100 IDs.
# 20181106-005019: looking up user records for 100 IDs.
# 20181106-005020: looking up user records for 100 IDs.
# 20181106-005022: looking up user records for 100 IDs.
# 20181106-005023: looking up user records for 100 IDs.
# 20181106-005024: looking up user records for 100 IDs.
# 20181106-005025: looking up user records for 100 IDs.
# 20181106-005027: looking up user records for 100 IDs.
# 20181106-005028: looking up user records for 100 IDs.
# 20181106-005029: looking up user records for 100 IDs.
# 20181106-005030: looking up user records for 100 IDs.
# 20181106-005031: looking up user records for 100 IDs.
# 20181106-005033: looking up user records for 100 IDs.
# 20181106-005034: looking up user records for 100 IDs.
# 20181106-005035: looking up user records for 100 IDs.
# 20181106-005036: looking up user records for 100 IDs.
# 20181106-005037: looking up user records for 100 IDs.
# 20181106-005038: looking up user records for 100 IDs.
# 20181106-005039: looking up user records for 100 IDs.
# 20181106-005041: looking up user records for 100 IDs.
# 20181106-005042: looking up user records for 100 IDs.
# 20181106-005043: looking up user records for 100 IDs.
# 20181106-005044: looking up user records for 100 IDs.
# 20181106-005046: looking up user records for 100 IDs.
# 20181106-005047: looking up user records for 100 IDs.
# 20181106-005048: looking up user records for 100 IDs.
# 20181106-005049: looking up user records for 100 IDs.
# 20181106-005051: looking up user records for 100 IDs.
# 20181106-005052: looking up user records for 100 IDs.
# 20181106-005053: looking up user records for 100 IDs.
# 20181106-005054: looking up user records for 100 IDs.
# 20181106-005055: looking up user records for 100 IDs.
# 20181106-005056: looking up user records for 100 IDs.
# 20181106-005058: looking up user records for 100 IDs.
# 20181106-005059: looking up user records for 100 IDs.
# 20181106-005100: looking up user records for 100 IDs.
# 20181106-005101: looking up user records for 100 IDs.
# 20181106-005103: looking up user records for 100 IDs.
# 20181106-005104: looking up user records for 100 IDs.
# 20181106-005105: looking up user records for 100 IDs.
# 20181106-005106: looking up user records for 100 IDs.
# 20181106-005107: looking up user records for 100 IDs.
# 20181106-005108: looking up user records for 100 IDs.
# 20181106-005110: looking up user records for 100 IDs.
# 20181106-005111: looking up user records for 100 IDs.
# 20181106-005112: looking up user records for 100 IDs.
# 20181106-005113: looking up user records for 100 IDs.
# 20181106-005114: looking up user records for 100 IDs.
# 20181106-005115: looking up user records for 100 IDs.
# 20181106-005116: looking up user records for 100 IDs.
# 20181106-005118: looking up user records for 100 IDs.
# 20181106-005119: looking up user records for 100 IDs.
# 20181106-005121: looking up user records for 100 IDs.
# 20181106-005122: looking up user records for 100 IDs.
# 20181106-005124: looking up user records for 100 IDs.
# 20181106-005125: looking up user records for 100 IDs.
# 20181106-005127: looking up user records for 100 IDs.
# 20181106-005128: looking up user records for 100 IDs.
# 20181106-005129: looking up user records for 100 IDs.
# 20181106-005130: looking up user records for 100 IDs.
# 20181106-005132: looking up user records for 100 IDs.
# 20181106-005133: looking up user records for 100 IDs.
# 20181106-005135: looking up user records for 100 IDs.
# 20181106-005136: looking up user records for 100 IDs.
# 20181106-005137: looking up user records for 100 IDs.
# 20181106-005138: looking up user records for 100 IDs.
# 20181106-005140: looking up user records for 100 IDs.
# 20181106-005141: looking up user records for 100 IDs.
# 20181106-005142: looking up user records for 100 IDs.
# 20181106-005143: looking up user records for 100 IDs.
# 20181106-005144: looking up user records for 100 IDs.
# 20181106-005146: looking up user records for 100 IDs.
# 20181106-005147: looking up user records for 100 IDs.
# 20181106-005148: looking up user records for 100 IDs.
# 20181106-005149: looking up user records for 100 IDs.
# 20181106-005150: looking up user records for 100 IDs.
# 20181106-005152: looking up user records for 100 IDs.
# 20181106-005153: looking up user records for 100 IDs.
# 20181106-005154: looking up user records for 100 IDs.
# 20181106-005155: looking up user records for 100 IDs.
# 20181106-005156: looking up user records for 100 IDs.
# 20181106-005158: looking up user records for 100 IDs.
# 20181106-005159: looking up user records for 100 IDs.
# 20181106-005200: looking up user records for 100 IDs.
# 20181106-005201: looking up user records for 100 IDs.
# 20181106-005203: looking up user records for 100 IDs.
# 20181106-005205: looking up user records for 100 IDs.
# 20181106-005206: looking up user records for 100 IDs.
# 20181106-005207: looking up user records for 100 IDs.
# 20181106-005208: looking up user records for 100 IDs.
# 20181106-005209: looking up user records for 100 IDs.
# 20181106-005211: looking up user records for 100 IDs.
# 20181106-005212: looking up user records for 100 IDs.
# 20181106-005213: looking up user records for 100 IDs.
# 20181106-005214: looking up user records for 100 IDs.
# 20181106-005215: looking up user records for 100 IDs.
# 20181106-005217: looking up user records for 100 IDs.
# 20181106-005218: looking up user records for 100 IDs.
# 20181106-005219: looking up user records for 100 IDs.
# 20181106-005220: looking up user records for 100 IDs.
# 20181106-005222: looking up user records for 100 IDs.
# 20181106-005223: looking up user records for 100 IDs.
# 20181106-005224: looking up user records for 100 IDs.
# 20181106-005225: looking up user records for 100 IDs.
# 20181106-005226: looking up user records for 100 IDs.
# 20181106-005228: looking up user records for 100 IDs.
# 20181106-005229: looking up user records for 100 IDs.
# 20181106-005230: looking up user records for 100 IDs.
# 20181106-005231: looking up user records for 100 IDs.
# 20181106-005232: looking up user records for 100 IDs.
# 20181106-005233: looking up user records for 100 IDs.
# 20181106-005235: looking up user records for 100 IDs.
# 20181106-005236: looking up user records for 100 IDs.
# 20181106-005237: looking up user records for 100 IDs.
# 20181106-005238: looking up user records for 100 IDs.
# 20181106-005239: looking up user records for 100 IDs.
# 20181106-005241: looking up user records for 100 IDs.
# 20181106-005242: looking up user records for 100 IDs.
# 20181106-005243: looking up user records for 100 IDs.
# 20181106-005244: looking up user records for 100 IDs.
# 20181106-005245: looking up user records for 100 IDs.
# 20181106-005246: looking up user records for 100 IDs.
# 20181106-005248: looking up user records for 100 IDs.
# 20181106-005249: looking up user records for 100 IDs.
# 20181106-005250: looking up user records for 100 IDs.
# 20181106-005252: looking up user records for 100 IDs.
# 20181106-005253: looking up user records for 100 IDs.
# 20181106-005254: looking up user records for 100 IDs.
# 20181106-005255: looking up user records for 100 IDs.
# 20181106-005256: looking up user records for 100 IDs.
# 20181106-005258: looking up user records for 100 IDs.
# 20181106-005259: looking up user records for 100 IDs.
# 20181106-005300: looking up user records for 100 IDs.
# 20181106-005301: looking up user records for 100 IDs.
# 20181106-005302: looking up user records for 100 IDs.
# 20181106-005304: looking up user records for 100 IDs.
# 20181106-005305: looking up user records for 100 IDs.
# 20181106-005306: looking up user records for 100 IDs.
# 20181106-005308: looking up user records for 100 IDs.
# 20181106-005309: looking up user records for 100 IDs.
# 20181106-005310: looking up user records for 100 IDs.
# 20181106-005312: looking up user records for 100 IDs.
# 20181106-005313: looking up user records for 100 IDs.
# 20181106-005314: looking up user records for 100 IDs.
# 20181106-005315: looking up user records for 100 IDs.
# 20181106-005316: looking up user records for 100 IDs.
# 20181106-005318: looking up user records for 100 IDs.
# 20181106-005319: looking up user records for 100 IDs.
# 20181106-005320: looking up user records for 100 IDs.
# 20181106-005322: looking up user records for 100 IDs.
# 20181106-005323: looking up user records for 100 IDs.
# 20181106-005324: looking up user records for 100 IDs.
# 20181106-005325: looking up user records for 100 IDs.
# 20181106-005326: looking up user records for 100 IDs.
# 20181106-005327: looking up user records for 100 IDs.
# 20181106-005328: looking up user records for 100 IDs.
# 20181106-005329: looking up user records for 100 IDs.
# 20181106-005331: looking up user records for 100 IDs.
# 20181106-005332: looking up user records for 100 IDs.
# 20181106-005333: looking up user records for 100 IDs.
# 20181106-005334: looking up user records for 100 IDs.
# 20181106-005335: looking up user records for 100 IDs.
# 20181106-005336: looking up user records for 100 IDs.
# 20181106-005337: looking up user records for 100 IDs.
# 20181106-005339: looking up user records for 100 IDs.
# 20181106-005340: looking up user records for 100 IDs.
# 20181106-005342: looking up user records for 100 IDs.
# 20181106-005343: looking up user records for 100 IDs.
# 20181106-005344: looking up user records for 100 IDs.
# 20181106-005346: looking up user records for 100 IDs.
# 20181106-005347: looking up user records for 100 IDs.
# 20181106-005348: looking up user records for 100 IDs.
# 20181106-005349: looking up user records for 100 IDs.
# 20181106-005350: looking up user records for 100 IDs.
# 20181106-005352: looking up user records for 100 IDs.
# 20181106-005353: looking up user records for 100 IDs.
# 20181106-005354: looking up user records for 100 IDs.
# 20181106-005355: looking up user records for 100 IDs.
# 20181106-005356: looking up user records for 100 IDs.
# 20181106-005357: looking up user records for 100 IDs.
# 20181106-005358: looking up user records for 100 IDs.
# 20181106-005400: looking up user records for 100 IDs.
# 20181106-005401: looking up user records for 100 IDs.
# 20181106-005402: looking up user records for 100 IDs.
# 20181106-005404: looking up user records for 100 IDs.
# 20181106-005405: looking up user records for 100 IDs.
# 20181106-005406: looking up user records for 100 IDs.
# 20181106-005407: looking up user records for 100 IDs.
# 20181106-005409: looking up user records for 100 IDs.
# 20181106-005411: looking up user records for 100 IDs.
# 20181106-005412: looking up user records for 100 IDs.
# 20181106-005413: looking up user records for 100 IDs.
# 20181106-005414: looking up user records for 100 IDs.
# 20181106-005415: looking up user records for 100 IDs.
# 20181106-005417: looking up user records for 100 IDs.
# 20181106-005418: looking up user records for 100 IDs.
# 20181106-005419: looking up user records for 100 IDs.
# 20181106-005420: looking up user records for 100 IDs.
# 20181106-005421: looking up user records for 100 IDs.
# 20181106-005423: looking up user records for 100 IDs.
# 20181106-005424: looking up user records for 100 IDs.
# 20181106-005425: looking up user records for 100 IDs.
# 20181106-005426: looking up user records for 100 IDs.
# 20181106-005427: looking up user records for 100 IDs.
# 20181106-005429: looking up user records for 100 IDs.
# 20181106-005430: looking up user records for 100 IDs.
# 20181106-005431: looking up user records for 100 IDs.
# 20181106-005432: looking up user records for 100 IDs.
# 20181106-005434: looking up user records for 100 IDs.
# 20181106-005435: looking up user records for 100 IDs.
# 20181106-005436: looking up user records for 100 IDs.
# 20181106-005437: looking up user records for 100 IDs.
# 20181106-005438: looking up user records for 100 IDs.
# 20181106-005440: looking up user records for 100 IDs.
# 20181106-005441: looking up user records for 100 IDs.
# 20181106-005442: looking up user records for 100 IDs.
# 20181106-005443: looking up user records for 100 IDs.
# 20181106-005444: looking up user records for 100 IDs.
# 20181106-005446: looking up user records for 100 IDs.
# 20181106-005447: looking up user records for 100 IDs.
# 20181106-005448: looking up user records for 100 IDs.
# 20181106-005449: looking up user records for 100 IDs.
# 20181106-005450: looking up user records for 100 IDs.
# 20181106-005452: looking up user records for 100 IDs.
# 20181106-005453: looking up user records for 100 IDs.
# 20181106-005454: looking up user records for 100 IDs.
# 20181106-005455: looking up user records for 100 IDs.
# 20181106-005456: looking up user records for 100 IDs.
# 20181106-005458: looking up user records for 100 IDs.
# 20181106-005459: looking up user records for 100 IDs.
# 20181106-005500: looking up user records for 100 IDs.
# 20181106-005501: looking up user records for 100 IDs.
# 20181106-005503: looking up user records for 100 IDs.
# 20181106-005504: looking up user records for 100 IDs.
# 20181106-005505: looking up user records for 100 IDs.
# 20181106-005506: looking up user records for 100 IDs.
# 20181106-005508: looking up user records for 100 IDs.
# 20181106-005509: looking up user records for 100 IDs.
# 20181106-005510: looking up user records for 100 IDs.
# 20181106-005511: looking up user records for 100 IDs.
# 20181106-005512: looking up user records for 100 IDs.
# 20181106-005514: looking up user records for 100 IDs.
# 20181106-005515: looking up user records for 100 IDs.
# 20181106-005516: looking up user records for 100 IDs.
# 20181106-005517: looking up user records for 100 IDs.
# 20181106-005518: looking up user records for 100 IDs.
# 20181106-005520: looking up user records for 100 IDs.
# 20181106-005521: looking up user records for 100 IDs.
# 20181106-005522: looking up user records for 100 IDs.
# 20181106-005523: looking up user records for 100 IDs.
# 20181106-005524: looking up user records for 100 IDs.
# 20181106-005526: looking up user records for 100 IDs.
# 20181106-005527: looking up user records for 100 IDs.
# 20181106-005528: looking up user records for 100 IDs.
# 20181106-005529: looking up user records for 100 IDs.
# 20181106-005530: looking up user records for 100 IDs.
# 20181106-005531: looking up user records for 100 IDs.
# 20181106-005532: looking up user records for 100 IDs.
# 20181106-005534: looking up user records for 100 IDs.
# 20181106-005535: looking up user records for 100 IDs.
# 20181106-005536: looking up user records for 100 IDs.
# 20181106-005537: looking up user records for 100 IDs.
# 20181106-005538: looking up user records for 100 IDs.
# 20181106-005540: looking up user records for 100 IDs.
# 20181106-005541: looking up user records for 100 IDs.
# 20181106-005542: looking up user records for 100 IDs.
# 20181106-005543: looking up user records for 100 IDs.
# 20181106-005545: looking up user records for 100 IDs.
# 20181106-005546: looking up user records for 100 IDs.
# 20181106-005547: looking up user records for 100 IDs.
# 20181106-005549: looking up user records for 100 IDs.
# 20181106-005550: looking up user records for 100 IDs.
# 20181106-005551: looking up user records for 100 IDs.
# 20181106-005552: looking up user records for 100 IDs.
# 20181106-005553: looking up user records for 100 IDs.
# 20181106-005554: looking up user records for 100 IDs.
# 20181106-005555: looking up user records for 100 IDs.
# 20181106-005557: looking up user records for 100 IDs.
# 20181106-005558: looking up user records for 100 IDs.
# 20181106-005559: looking up user records for 100 IDs.
# 20181106-005600: looking up user records for 100 IDs.
# 20181106-005601: looking up user records for 100 IDs.
# 20181106-005603: looking up user records for 100 IDs.
# 20181106-005604: looking up user records for 100 IDs.
# 20181106-005605: looking up user records for 100 IDs.
# 20181106-005607: looking up user records for 100 IDs.
# 20181106-005608: looking up user records for 100 IDs.
# 20181106-005609: looking up user records for 100 IDs.
# 20181106-005610: looking up user records for 100 IDs.
# 20181106-005611: looking up user records for 100 IDs.
# 20181106-005613: looking up user records for 100 IDs.
# 20181106-005614: looking up user records for 100 IDs.
# 20181106-005615: looking up user records for 100 IDs.
# 20181106-005616: looking up user records for 100 IDs.
# 20181106-005617: looking up user records for 100 IDs.
# 20181106-005618: looking up user records for 100 IDs.
# 20181106-005620: looking up user records for 100 IDs.
# 20181106-005621: looking up user records for 100 IDs.
# 20181106-005622: looking up user records for 100 IDs.
# 20181106-005623: looking up user records for 100 IDs.
# 20181106-005624: looking up user records for 100 IDs.
# 20181106-005625: looking up user records for 100 IDs.
# 20181106-005627: looking up user records for 100 IDs.
# 20181106-005628: looking up user records for 100 IDs.
# 20181106-005629: looking up user records for 100 IDs.
# 20181106-005630: looking up user records for 100 IDs.
# 20181106-005631: looking up user records for 100 IDs.
# 20181106-005632: looking up user records for 100 IDs.
# 20181106-005633: looking up user records for 100 IDs.
# 20181106-005634: looking up user records for 100 IDs.
# 20181106-005636: looking up user records for 100 IDs.
# 20181106-005637: looking up user records for 100 IDs.
# 20181106-005638: looking up user records for 100 IDs.
# 20181106-005639: looking up user records for 100 IDs.
# 20181106-005640: looking up user records for 100 IDs.
# 20181106-005642: looking up user records for 100 IDs.
# 20181106-005643: looking up user records for 100 IDs.
# 20181106-005645: looking up user records for 100 IDs.
# 20181106-005646: looking up user records for 100 IDs.
# 20181106-005647: looking up user records for 100 IDs.
# 20181106-005649: looking up user records for 100 IDs.
# 20181106-005650: looking up user records for 100 IDs.
# 20181106-005652: looking up user records for 100 IDs.
# 20181106-005653: looking up user records for 100 IDs.
# 20181106-005654: looking up user records for 100 IDs.
# 20181106-005655: looking up user records for 100 IDs.
# 20181106-005657: looking up user records for 100 IDs.
# 20181106-005658: looking up user records for 100 IDs.
# 20181106-005659: looking up user records for 100 IDs.
# 20181106-005700: looking up user records for 100 IDs.
# 20181106-005701: looking up user records for 100 IDs.
# 20181106-005703: looking up user records for 100 IDs.
# 20181106-005704: looking up user records for 100 IDs.
# 20181106-005705: looking up user records for 100 IDs.
# 20181106-005706: looking up user records for 100 IDs.
# 20181106-005708: looking up user records for 100 IDs.
# 20181106-005709: looking up user records for 100 IDs.
# 20181106-005710: looking up user records for 100 IDs.
# 20181106-005711: looking up user records for 100 IDs.
# 20181106-005712: looking up user records for 100 IDs.
# 20181106-005714: looking up user records for 100 IDs.
# 20181106-005715: looking up user records for 100 IDs.
# 20181106-005716: looking up user records for 100 IDs.
# 20181106-005717: looking up user records for 100 IDs.
# 20181106-005719: looking up user records for 100 IDs.
# 20181106-005720: looking up user records for 100 IDs.
# 20181106-005721: looking up user records for 100 IDs.
# 20181106-005722: looking up user records for 100 IDs.
# 20181106-005723: looking up user records for 100 IDs.
# 20181106-005724: looking up user records for 100 IDs.
# 20181106-005726: looking up user records for 100 IDs.
# 20181106-005727: looking up user records for 100 IDs.
# 20181106-005728: looking up user records for 100 IDs.
# 20181106-005729: looking up user records for 100 IDs.
# 20181106-005730: looking up user records for 100 IDs.
# 20181106-005732: looking up user records for 100 IDs.
# 20181106-005733: looking up user records for 100 IDs.
# 20181106-005734: looking up user records for 100 IDs.
# 20181106-005735: looking up user records for 100 IDs.
# 20181106-005736: looking up user records for 100 IDs.
# 20181106-005737: looking up user records for 100 IDs.
# 20181106-005739: looking up user records for 100 IDs.
# 20181106-005740: looking up user records for 100 IDs.
# 20181106-005741: looking up user records for 100 IDs.
# 20181106-005743: looking up user records for 100 IDs.
# 20181106-005744: looking up user records for 100 IDs.
# 20181106-005745: looking up user records for 100 IDs.
# 20181106-005746: looking up user records for 100 IDs.
# 20181106-005747: looking up user records for 100 IDs.
# 20181106-005749: looking up user records for 100 IDs.
# 20181106-005750: looking up user records for 100 IDs.
# 20181106-005751: looking up user records for 100 IDs.
# 20181106-005753: looking up user records for 100 IDs.
# 20181106-005754: looking up user records for 100 IDs.
# 20181106-005755: looking up user records for 100 IDs.
# 20181106-005756: looking up user records for 100 IDs.
# 20181106-005757: looking up user records for 100 IDs.
# 20181106-005759: looking up user records for 100 IDs.
# 20181106-005800: looking up user records for 100 IDs.
# 20181106-005801: looking up user records for 100 IDs.
# 20181106-005802: looking up user records for 100 IDs.
# 20181106-005804: looking up user records for 100 IDs.
# 20181106-005805: looking up user records for 100 IDs.
# 20181106-005807: looking up user records for 100 IDs.
# 20181106-005808: looking up user records for 100 IDs.
# 20181106-005809: looking up user records for 100 IDs.
# 20181106-005810: looking up user records for 100 IDs.
# 20181106-005811: looking up user records for 100 IDs.
# 20181106-005812: looking up user records for 100 IDs.
# 20181106-005814: looking up user records for 100 IDs.
# 20181106-005815: looking up user records for 100 IDs.
# 20181106-005816: looking up user records for 100 IDs.
# 20181106-005817: looking up user records for 100 IDs.
# 20181106-005818: looking up user records for 100 IDs.
# 20181106-005820: looking up user records for 100 IDs.
# 20181106-005821: looking up user records for 100 IDs.
# 20181106-005822: looking up user records for 100 IDs.
# 20181106-005823: looking up user records for 100 IDs.
# 20181106-005825: looking up user records for 100 IDs.
# 20181106-005826: looking up user records for 100 IDs.
# 20181106-005827: looking up user records for 100 IDs.
# 20181106-005829: looking up user records for 100 IDs.
# 20181106-005830: looking up user records for 100 IDs.
# 20181106-005831: looking up user records for 100 IDs.
# 20181106-005832: looking up user records for 100 IDs.
# 20181106-005833: looking up user records for 100 IDs.
# 20181106-005834: looking up user records for 100 IDs.
# 20181106-005836: looking up user records for 100 IDs.
# 20181106-005837: looking up user records for 100 IDs.
# 20181106-005838: looking up user records for 100 IDs.
# 20181106-005839: looking up user records for 100 IDs.
# 20181106-005840: looking up user records for 100 IDs.
# 20181106-005841: looking up user records for 100 IDs.
# 20181106-005843: looking up user records for 100 IDs.
# 20181106-005844: looking up user records for 100 IDs.
# 20181106-005845: looking up user records for 100 IDs.
# 20181106-005846: looking up user records for 100 IDs.
# 20181106-005847: looking up user records for 100 IDs.
# 20181106-005849: looking up user records for 100 IDs.
# 20181106-005850: looking up user records for 100 IDs.
# 20181106-005851: looking up user records for 100 IDs.
# 20181106-005852: looking up user records for 100 IDs.
# 20181106-005853: looking up user records for 100 IDs.
# 20181106-005854: looking up user records for 100 IDs.
# 20181106-005855: looking up user records for 100 IDs.
# 20181106-005857: looking up user records for 100 IDs.
# 20181106-005858: looking up user records for 100 IDs.
# 20181106-005859: looking up user records for 100 IDs.
# 20181106-005900: looking up user records for 100 IDs.
# 20181106-005901: looking up user records for 100 IDs.
# 20181106-005903: looking up user records for 100 IDs.
# 20181106-005904: looking up user records for 100 IDs.
# 20181106-005905: looking up user records for 100 IDs.
# 20181106-005907: looking up user records for 100 IDs.
# 20181106-005908: looking up user records for 100 IDs.
# 20181106-005909: looking up user records for 100 IDs.
# 20181106-005910: looking up user records for 100 IDs.
# 20181106-005911: looking up user records for 100 IDs.
# 20181106-005912: looking up user records for 100 IDs.
# 20181106-005914: looking up user records for 100 IDs.
# 20181106-005915: looking up user records for 100 IDs.
# 20181106-005916: looking up user records for 100 IDs.
# 20181106-005917: looking up user records for 100 IDs.
# 20181106-005918: looking up user records for 100 IDs.
# 20181106-005919: looking up user records for 100 IDs.
# 20181106-005921: looking up user records for 100 IDs.
# 20181106-005922: looking up user records for 100 IDs.
# 20181106-005923: looking up user records for 100 IDs.
# 20181106-005924: looking up user records for 100 IDs.
# 20181106-005925: looking up user records for 100 IDs.
# 20181106-005926: looking up user records for 100 IDs.
# 20181106-005927: looking up user records for 100 IDs.
# 20181106-005928: looking up user records for 100 IDs.
# 20181106-005930: looking up user records for 100 IDs.
# 20181106-005931: looking up user records for 100 IDs.
# 20181106-005932: looking up user records for 100 IDs.
# 20181106-005933: looking up user records for 100 IDs.
# 20181106-005934: looking up user records for 100 IDs.
# 20181106-005935: looking up user records for 100 IDs.
# 20181106-005937: looking up user records for 100 IDs.
# 20181106-005938: looking up user records for 100 IDs.
# 20181106-005939: looking up user records for 100 IDs.
# 20181106-005940: looking up user records for 100 IDs.
# 20181106-005942: looking up user records for 100 IDs.
# 20181106-005943: looking up user records for 100 IDs.
# 20181106-005944: looking up user records for 100 IDs.
# 20181106-005945: looking up user records for 100 IDs.
# 20181106-005947: looking up user records for 100 IDs.
# 20181106-005948: looking up user records for 100 IDs.
# 20181106-005949: looking up user records for 100 IDs.
# 20181106-005950: looking up user records for 100 IDs.
# 20181106-005951: looking up user records for 100 IDs.
# 20181106-005952: looking up user records for 100 IDs.
# 20181106-005953: looking up user records for 100 IDs.
# 20181106-005955: looking up user records for 100 IDs.
# 20181106-005956: looking up user records for 100 IDs.
# 20181106-005957: looking up user records for 100 IDs.
# 20181106-005958: looking up user records for 100 IDs.
# 20181106-005959: looking up user records for 100 IDs.
# 20181106-010000: looking up user records for 100 IDs.
# 20181106-010002: looking up user records for 100 IDs.
# 20181106-010003: looking up user records for 100 IDs.
# 20181106-010004: looking up user records for 100 IDs.
# 20181106-010006: looking up user records for 100 IDs.
# 20181106-010007: looking up user records for 100 IDs.
# 20181106-010008: looking up user records for 100 IDs.
# 20181106-010010: looking up user records for 100 IDs.
# 20181106-010011: looking up user records for 100 IDs.
# 20181106-010012: looking up user records for 100 IDs.
# 20181106-010014: looking up user records for 100 IDs.
# 20181106-010015: looking up user records for 100 IDs.
# 20181106-010016: looking up user records for 100 IDs.
# 20181106-010017: looking up user records for 100 IDs.
# 20181106-010018: looking up user records for 100 IDs.
# 20181106-010019: looking up user records for 100 IDs.
# 20181106-010021: looking up user records for 100 IDs.
# 20181106-010022: looking up user records for 100 IDs.
# 20181106-010023: looking up user records for 100 IDs.
# 20181106-010024: looking up user records for 100 IDs.
# 20181106-010025: looking up user records for 100 IDs.
# 20181106-010027: looking up user records for 100 IDs.
# 20181106-010028: looking up user records for 100 IDs.
# 20181106-010029: looking up user records for 100 IDs.
# 20181106-010030: looking up user records for 100 IDs.
# 20181106-010031: looking up user records for 100 IDs.
# 20181106-010033: looking up user records for 100 IDs.
# 20181106-010034: looking up user records for 100 IDs.
# 20181106-010035: looking up user records for 100 IDs.
# 20181106-010036: looking up user records for 100 IDs.
# 20181106-010037: looking up user records for 100 IDs.
# 20181106-010039: looking up user records for 100 IDs.
# 20181106-010040: looking up user records for 100 IDs.
# 20181106-010041: looking up user records for 100 IDs.
# 20181106-010042: looking up user records for 100 IDs.
# 20181106-010043: looking up user records for 100 IDs.
# 20181106-010045: looking up user records for 100 IDs.
# 20181106-010046: looking up user records for 100 IDs.
# 20181106-010047: looking up user records for 100 IDs.
# 20181106-010048: looking up user records for 100 IDs.
# 20181106-010049: looking up user records for 100 IDs.
# 20181106-010050: looking up user records for 100 IDs.
# 20181106-010052: looking up user records for 100 IDs.
# 20181106-010053: looking up user records for 100 IDs.
# 20181106-010054: looking up user records for 100 IDs.
# 20181106-010055: looking up user records for 100 IDs.
# 20181106-010057: looking up user records for 100 IDs.
# 20181106-010058: looking up user records for 100 IDs.
# 20181106-010059: looking up user records for 100 IDs.
# 20181106-010100: looking up user records for 100 IDs.
# 20181106-010101: looking up user records for 100 IDs.
# 20181106-010103: looking up user records for 100 IDs.
# 20181106-010104: looking up user records for 100 IDs.
# 20181106-010105: looking up user records for 100 IDs.
# 20181106-010106: looking up user records for 100 IDs.
# 20181106-010108: looking up user records for 100 IDs.
# 20181106-010109: looking up user records for 100 IDs.
# 20181106-010110: looking up user records for 100 IDs.
# 20181106-010111: looking up user records for 100 IDs.
# 20181106-010113: looking up user records for 100 IDs.
# 20181106-010114: looking up user records for 100 IDs.
# 20181106-010115: looking up user records for 100 IDs.
# 20181106-010116: looking up user records for 100 IDs.
# 20181106-010117: looking up user records for 100 IDs.
# 20181106-010119: looking up user records for 100 IDs.
# 20181106-010120: looking up user records for 100 IDs.
# 20181106-010121: looking up user records for 100 IDs.
# 20181106-010122: looking up user records for 100 IDs.
# 20181106-010123: looking up user records for 100 IDs.
# 20181106-010125: looking up user records for 100 IDs.
# 20181106-010126: looking up user records for 100 IDs.
# 20181106-010127: looking up user records for 100 IDs.
# 20181106-010128: looking up user records for 100 IDs.
# 20181106-010129: looking up user records for 100 IDs.
# 20181106-010130: looking up user records for 100 IDs.
# 20181106-010132: looking up user records for 100 IDs.
# 20181106-010133: looking up user records for 100 IDs.
# 20181106-010134: looking up user records for 100 IDs.
# 20181106-010135: looking up user records for 100 IDs.
# 20181106-010137: looking up user records for 100 IDs.
# 20181106-010138: looking up user records for 100 IDs.
# 20181106-010139: looking up user records for 100 IDs.
# 20181106-010140: looking up user records for 100 IDs.
# 20181106-010142: looking up user records for 100 IDs.
# 20181106-010143: looking up user records for 100 IDs.
# 20181106-010144: looking up user records for 100 IDs.
# 20181106-010146: looking up user records for 100 IDs.
# 20181106-010147: looking up user records for 100 IDs.
# 20181106-010148: looking up user records for 100 IDs.
# 20181106-010149: looking up user records for 100 IDs.
# 20181106-010151: looking up user records for 100 IDs.
# 20181106-010152: looking up user records for 100 IDs.
# 20181106-010153: looking up user records for 100 IDs.
# 20181106-010154: looking up user records for 100 IDs.
# 20181106-010156: looking up user records for 100 IDs.
# 20181106-010157: looking up user records for 100 IDs.
# 20181106-010158: looking up user records for 100 IDs.
# 20181106-010159: looking up user records for 100 IDs.
# 20181106-010200: looking up user records for 100 IDs.
# 20181106-010202: looking up user records for 100 IDs.
# 20181106-010203: looking up user records for 100 IDs.
# 20181106-010204: looking up user records for 100 IDs.
# 20181106-010205: looking up user records for 100 IDs.
# 20181106-010206: looking up user records for 100 IDs.
# 20181106-010207: looking up user records for 100 IDs.
# 20181106-010209: looking up user records for 100 IDs.
# 20181106-010210: looking up user records for 100 IDs.
# 20181106-010211: looking up user records for 100 IDs.
# 20181106-010212: looking up user records for 100 IDs.
# 20181106-010213: looking up user records for 100 IDs.
# 20181106-010215: looking up user records for 100 IDs.
# 20181106-010216: looking up user records for 100 IDs.
# 20181106-010217: looking up user records for 100 IDs.
# 20181106-010218: looking up user records for 100 IDs.
# 20181106-010219: looking up user records for 100 IDs.
# 20181106-010220: looking up user records for 100 IDs.
# 20181106-010222: looking up user records for 100 IDs.
# 20181106-010223: looking up user records for 100 IDs.
# 20181106-010224: looking up user records for 100 IDs.
# 20181106-010225: looking up user records for 100 IDs.
# 20181106-010226: looking up user records for 100 IDs.
# 20181106-010228: looking up user records for 100 IDs.
# 20181106-010229: looking up user records for 100 IDs.
# 20181106-010230: looking up user records for 100 IDs.
# 20181106-010231: looking up user records for 100 IDs.
# 20181106-010232: looking up user records for 100 IDs.
# 20181106-010234: looking up user records for 100 IDs.
# 20181106-010235: looking up user records for 100 IDs.
# 20181106-010236: looking up user records for 100 IDs.
# 20181106-010237: looking up user records for 100 IDs.
# 20181106-010238: looking up user records for 100 IDs.
# 20181106-010240: looking up user records for 100 IDs.
# 20181106-010241: looking up user records for 100 IDs.
# 20181106-010242: looking up user records for 100 IDs.
# 20181106-010243: looking up user records for 100 IDs.
# 20181106-010244: looking up user records for 100 IDs.
# 20181106-010245: looking up user records for 100 IDs.
# 20181106-010247: looking up user records for 100 IDs.
# 20181106-010248: looking up user records for 100 IDs.
# 20181106-010249: looking up user records for 100 IDs.
# 20181106-010250: looking up user records for 100 IDs.
# 20181106-010251: looking up user records for 100 IDs.
# 20181106-010253: looking up user records for 17 IDs.
# 20181106-010253:  users pulled:  93217
# total failures: 0

# %%
# Now let's write out all the records. I wrote some functions to help.
with open(ofile_name,'w') as ofile :
    write_user_rec_headers(ofile)
    for id, rec in all_records.items() :
        write_user_rec(ofile, rec)
