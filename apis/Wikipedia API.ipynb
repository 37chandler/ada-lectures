# %% [markdown]
# # Accessing the Wikipedia API
# This notebook pulls some information from the Wikipedia API. This API is nice because it doesn't require authentication. (The Twitter API requires authentication--that's a necessary process to go through, but requires some work.)

# %%
import requests

wikipedia_api_url = "https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmlimit=10"

# %% [markdown]
# We can start by just building a simple query, getting 10 people born in 1973. We will use the delightful and amazing [`requests`](http://docs.python-requests.org/en/master/) library in Python. The format of the URL is based on a bunch of reading about the [Wikipedia API](https://www.mediawiki.org/wiki/API:Categorymembers) and trial and error. And error.

# %%
full_url = wikipedia_api_url + "&cmtitle=Category:1973_births"

print(full_url)

r = requests.get(full_url)
# Out:
# https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmlimit=10&cmtitle=Category:1973_births

# %%
from pprint import pprint

# %% [markdown]
# Let's use the `pprint` (for "pretty print") to print out the `json` object that returns from the API call.

# %%
pprint(r.json())
# Out:
# {'batchcomplete': '',
#  'continue': {'cmcontinue': 'page|292b2b294d06042949294b292b03062949294b292b04292b2b294d011e01dcc0dcc0dcc0dc08|54679534',
#               'continue': '-||'},
#  'query': {'categorymembers': [{'ns': 0, 'pageid': 3657357, 'title': 'A-do'},
#                                {'ns': 0,
#                                 'pageid': 16159192,
#                                 'title': 'Jacob Aagaard'},
#                                {'ns': 0, 'pageid': 22785402, 'title': 'Aamani'},
#                                {'ns': 0,
#                                 'pageid': 14516619,
#                                 'title': 'Hallvard Aamlid'},
#                                {'ns': 0,
#                                 'pageid': 13700991,
#                                 'title': 'Jason Aaron'},
#                                {'ns': 0,
#                                 'pageid': 6284418,
#                                 'title': 'Ann Kristin Aarønes'},
#                                {'ns': 0,
#                                 'pageid': 14513688,
#                                 'title': 'John-Ragnar Aarset'},
#                                {'ns': 0,
#                                 'pageid': 55915264,
#                                 'title': 'Dagfinn Aarskog (bobsleigh)'},
#                                {'ns': 0,
#                                 'pageid': 36759928,
#                                 'title': 'Eileen Abad'},
#                                {'ns': 0,
#                                 'pageid': 6822011,
#                                 'title': 'Aydo Abay'}]}}

# %% [markdown]
# Feel free to click on the link above. You'll see a `pprint` version of what was returned. Thanks Wikipedia!
#
# In this next cell, type `r.` and a tab and look at all the options you have to complete the request object.

# %%
r.url
# Out:
# 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmlimit=10&cmtitle=Category:1973_births'

# %% [markdown]
# One of the most useful is `r.json()`.

# %%
r.json()
# Out:
# {'batchcomplete': '',
#  'continue': {'cmcontinue': 'page|292b2b294d06042949294b292b03062949294b292b04292b2b294d011e01dcc0dcc0dcc0dc08|54679534',
#   'continue': '-||'},
#  'query': {'categorymembers': [{'ns': 0, 'pageid': 3657357, 'title': 'A-do'},
#    {'ns': 0, 'pageid': 16159192, 'title': 'Jacob Aagaard'},
#    {'ns': 0, 'pageid': 22785402, 'title': 'Aamani'},
#    {'ns': 0, 'pageid': 14516619, 'title': 'Hallvard Aamlid'},
#    {'ns': 0, 'pageid': 13700991, 'title': 'Jason Aaron'},
#    {'ns': 0, 'pageid': 6284418, 'title': 'Ann Kristin Aarønes'},
#    {'ns': 0, 'pageid': 14513688, 'title': 'John-Ragnar Aarset'},
#    {'ns': 0, 'pageid': 55915264, 'title': 'Dagfinn Aarskog (bobsleigh)'},
#    {'ns': 0, 'pageid': 36759928, 'title': 'Eileen Abad'},
#    {'ns': 0, 'pageid': 6822011, 'title': 'Aydo Abay'}]}}

# %% [markdown]
# Compare these results to the entry: https://en.wikipedia.org/wiki/Category:1973_births.
#
# JSON objects look a lot like Python dictonaries. In this case, we've got three main keys, `batchcomplete`, `continue`, and `query`.

# %%
for item in r.json() :
    print(item)
# Out:
# batchcomplete
# continue
# query

# %%
for item in r.json()['query'] :
    print(item)
# Out:
# categorymembers

# %% [markdown]
# `batchcomplete` tells us if we're done, I think. `continue` is used to continue through the results since we can't request more than 500 items at once. And `query` has the results.

# %%
for item in r.json()['query']['categorymembers'] :
    print(item)
# Out:
# {'pageid': 3657357, 'ns': 0, 'title': 'A-do'}
# {'pageid': 16159192, 'ns': 0, 'title': 'Jacob Aagaard'}
# {'pageid': 22785402, 'ns': 0, 'title': 'Aamani'}
# {'pageid': 14516619, 'ns': 0, 'title': 'Hallvard Aamlid'}
# {'pageid': 13700991, 'ns': 0, 'title': 'Jason Aaron'}
# {'pageid': 6284418, 'ns': 0, 'title': 'Ann Kristin Aarønes'}
# {'pageid': 14513688, 'ns': 0, 'title': 'John-Ragnar Aarset'}
# {'pageid': 55915264, 'ns': 0, 'title': 'Dagfinn Aarskog (bobsleigh)'}
# {'pageid': 36759928, 'ns': 0, 'title': 'Eileen Abad'}
# {'pageid': 6822011, 'ns': 0, 'title': 'Aydo Abay'}

# %% [markdown]
# Now let's build a list of everyone born in 1973. I've added a way to get out using an interation counter. Change the `iteration > n` line to get a different number of pages of results or make it something like 50 to get all the names.

# %%
# Let's build up our request in a more sustainable way
req = {'action':'query',
       'format':'json',
       'list':'categorymembers',
       'cmlimit':500, # move the limit up to the max we can do.
       'cmtitle':'Category:1973_births'}

last_continue = {} # used to keep track of how far we've gone. 
iteration = 1
pages = 0

names = []

while True :
    # Modify it with the values returned in the 'continue' section of the last result.
    req.update(last_continue)
    
    # Call API
    result = requests.get('https://en.wikipedia.org/w/api.php', params=req).json() 
    
    pages += 1
    
    # Grab the names
    for item in result['query']['categorymembers'] :
        names.append(item['title'])
    
    # keep track of our iteration so we can exit if this runs forever
    iteration += 1
    
    # Can we get out?
    if 'continue' not in result :
        break
    else :
        last_continue = result['continue']
    
    if iteration > 300 :
        # it's useful to have a way out of while statements,
        # particularly ones that are framed as "while True"
        break 

print("We pulled {} pages".format(pages))
# Out:
# We pulled 25 pages

# %%
pprint(result)
# Out:
# {'batchcomplete': '',
#  'query': {'categorymembers': [{'ns': 0,
#                                 'pageid': 4597415,
#                                 'title': 'Miho Yamada'},
#                                {'ns': 0,
#                                 'pageid': 52517761,
#                                 'title': 'Miho Yamada (gymnast)'},
#                                {'ns': 0,
#                                 'pageid': 2104249,
#                                 'title': 'Sulim Yamadayev'},
#                                {'ns': 0,
#                                 'pageid': 22467670,
#                                 'title': 'Hidetada Yamagishi'},
#                                {'ns': 0,
#                                 'pageid': 8751597,
#                                 'title': 'Eri Yamaguchi'},
#                                {'ns': 0,
#                                 'pageid': 26613361,
#                                 'title': 'Takayuki Yamaguchi (footballer)'},
#                                {'ns': 0,
#                                 'pageid': 30767951,
#                                 'title': 'Hiroto Yamamura'},
#                                {'ns': 0,
#                                 'pageid': 27578701,
#                                 'title': 'Mitsunori Yamao'},
#                                {'ns': 0,
#                                 'pageid': 47348627,
#                                 'title': 'Shiko Yamashita'},
#                                {'ns': 0,
#                                 'pageid': 13754481,
#                                 'title': 'Koichi Yamauchi'},
#                                {'ns': 0,
#                                 'pageid': 6937854,
#                                 'title': 'Mara Yamauchi'},
#                                {'ns': 0,
#                                 'pageid': 41604249,
#                                 'title': 'Yasuyuki Yamauchi'},
#                                {'ns': 0, 'pageid': 7852271, 'title': 'Yan Wei'},
#                                {'ns': 0,
#                                 'pageid': 34641368,
#                                 'title': 'Yan Xiandong'},
#                                {'ns': 0,
#                                 'pageid': 4431780,
#                                 'title': 'Kaya Yanar'},
#                                {'ns': 0,
#                                 'pageid': 12051027,
#                                 'title': 'Darcel Yandzi'},
#                                {'ns': 0,
#                                 'pageid': 16684624,
#                                 'title': 'Nacho Yáñez'},
#                                {'ns': 0,
#                                 'pageid': 2231944,
#                                 'title': 'Yang Bo (gymnast)'},
#                                {'ns': 0,
#                                 'pageid': 37231782,
#                                 'title': 'Brian Yang'},
#                                {'ns': 0,
#                                 'pageid': 58407364,
#                                 'title': 'Charles Yang (linguist)'},
#                                {'ns': 0,
#                                 'pageid': 14838591,
#                                 'title': 'Yang Cheng-hsing'},
#                                {'ns': 0,
#                                 'pageid': 56485165,
#                                 'title': 'Yang Chunyuan'},
#                                {'ns': 0,
#                                 'pageid': 53558597,
#                                 'title': 'Yang Gam'},
#                                {'ns': 0,
#                                 'pageid': 7619558,
#                                 'title': 'Gene Luen Yang'},
#                                {'ns': 0,
#                                 'pageid': 34800642,
#                                 'title': 'Yang Roy-sung'},
#                                {'ns': 0,
#                                 'pageid': 8704222,
#                                 'title': 'Yang Siju'},
#                                {'ns': 0,
#                                 'pageid': 13004166,
#                                 'title': 'Yang Yongjian'},
#                                {'ns': 0,
#                                 'pageid': 43200742,
#                                 'title': 'Soname Yangchen'},
#                                {'ns': 0,
#                                 'pageid': 53058173,
#                                 'title': 'Vasyl Yanitskyi'},
#                                {'ns': 0,
#                                 'pageid': 34949869,
#                                 'title': 'Oleksandr Yanukovych'},
#                                {'ns': 0, 'pageid': 13322802, 'title': 'Yao Ye'},
#                                {'ns': 0,
#                                 'pageid': 36596245,
#                                 'title': 'Chris Yarangga'},
#                                {'ns': 0,
#                                 'pageid': 2580790,
#                                 'title': 'Cedric Yarbrough'},
#                                {'ns': 0,
#                                 'pageid': 47145972,
#                                 'title': 'Yevgeni Yarkov'},
#                                {'ns': 0,
#                                 'pageid': 47509389,
#                                 'title': 'Curtis Yarvin'},
#                                {'ns': 0,
#                                 'pageid': 6067942,
#                                 'title': 'Corissa Yasen'},
#                                {'ns': 0,
#                                 'pageid': 318752,
#                                 'title': 'Alexei Yashin'},
#                                {'ns': 0,
#                                 'pageid': 24760778,
#                                 'title': 'Konstantin Yashin'},
#                                {'ns': 0,
#                                 'pageid': 38286425,
#                                 'title': 'Nida Yasir'},
#                                {'ns': 0,
#                                 'pageid': 58543567,
#                                 'title': 'Yasue Maetake'},
#                                {'ns': 0,
#                                 'pageid': 987839,
#                                 'title': 'Choke Yasuoka'},
#                                {'ns': 0,
#                                 'pageid': 48498834,
#                                 'title': 'Aaron Yates (motorcyclist)'},
#                                {'ns': 0,
#                                 'pageid': 2576709,
#                                 'title': 'Yau Kin Wai'},
#                                {'ns': 0,
#                                 'pageid': 7491367,
#                                 'title': 'Joachim Yaw'},
#                                {'ns': 0,
#                                 'pageid': 34973727,
#                                 'title': 'Reza Yazdani (singer)'},
#                                {'ns': 0,
#                                 'pageid': 30766599,
#                                 'title': 'Ye Ji-won'},
#                                {'ns': 0,
#                                 'pageid': 12281915,
#                                 'title': 'Richard Yeabsley'},
#                                {'ns': 0,
#                                 'pageid': 57367679,
#                                 'title': 'Dmitry Yefremov (footballer, born '
#                                          '1974)'},
#                                {'ns': 0,
#                                 'pageid': 23760653,
#                                 'title': 'Sergei Viktorovich Yegorov'},
#                                {'ns': 0,
#                                 'pageid': 28342818,
#                                 'title': 'Yeh Wei-tze'},
#                                {'ns': 0,
#                                 'pageid': 6016836,
#                                 'title': 'Chandra Sekhar Yeleti'},
#                                {'ns': 0,
#                                 'pageid': 47364524,
#                                 'title': 'Vitali Yelsukov'},
#                                {'ns': 0,
#                                 'pageid': 4217140,
#                                 'title': 'Hande Yener'},
#                                {'ns': 0,
#                                 'pageid': 11826381,
#                                 'title': 'Mike Yeo'},
#                                {'ns': 0,
#                                 'pageid': 2916551,
#                                 'title': 'Simon Yeo'},
#                                {'ns': 0,
#                                 'pageid': 11914512,
#                                 'title': 'Nikki Yeoh'},
#                                {'ns': 0,
#                                 'pageid': 23660413,
#                                 'title': 'Poh Ling Yeow'},
#                                {'ns': 0,
#                                 'pageid': 22750414,
#                                 'title': 'Oksana Yermakova'},
#                                {'ns': 0,
#                                 'pageid': 3257940,
#                                 'title': 'Aleksandr Yeryshov'},
#                                {'ns': 0,
#                                 'pageid': 46698058,
#                                 'title': 'Mikhail Yevseyev'},
#                                {'ns': 0,
#                                 'pageid': 6258693,
#                                 'title': 'Cem Yılmaz'},
#                                {'ns': 0,
#                                 'pageid': 17347878,
#                                 'title': 'Lev Yilmaz'},
#                                {'ns': 0,
#                                 'pageid': 49366936,
#                                 'title': 'Chi Jang Yin'},
#                                {'ns': 0,
#                                 'pageid': 19407879,
#                                 'title': 'Yin Lichuan'},
#                                {'ns': 0,
#                                 'pageid': 5675990,
#                                 'title': 'Gloria Yip'},
#                                {'ns': 0,
#                                 'pageid': 31174167,
#                                 'title': 'Luchia Yishak'},
#                                {'ns': 0,
#                                 'pageid': 21552779,
#                                 'title': 'Raymond Yiu'},
#                                {'ns': 0,
#                                 'pageid': 3207605,
#                                 'title': 'Marko Yli-Hannuksela'},
#                                {'ns': 0,
#                                 'pageid': 31973610,
#                                 'title': 'Visar Ymeri'},
#                                {'ns': 0, 'pageid': 15706647, 'title': 'Yogie'},
#                                {'ns': 0,
#                                 'pageid': 5565076,
#                                 'title': 'Charles Yohane'},
#                                {'ns': 0,
#                                 'pageid': 51593130,
#                                 'title': 'Shuhei Yomoda'},
#                                {'ns': 0,
#                                 'pageid': 13718264,
#                                 'title': 'Aaron Yonda'},
#                                {'ns': 0,
#                                 'pageid': 26798878,
#                                 'title': 'Hiromasa Yonebayashi'},
#                                {'ns': 0,
#                                 'pageid': 30049544,
#                                 'title': 'Vladimir Yonkov'},
#                                {'ns': 0,
#                                 'pageid': 32255646,
#                                 'title': 'Frédéric Yonnet'},
#                                {'ns': 0,
#                                 'pageid': 6456564,
#                                 'title': 'Yoo Chae-yeong'},
#                                {'ns': 0,
#                                 'pageid': 49172892,
#                                 'title': 'Yoo Jae-myung'},
#                                {'ns': 0,
#                                 'pageid': 36296167,
#                                 'title': 'Yoo Ok-ryul'},
#                                {'ns': 0,
#                                 'pageid': 36830917,
#                                 'title': 'Yoo Sang-soo'},
#                                {'ns': 0,
#                                 'pageid': 22001865,
#                                 'title': 'Yoo Young-sil'},
#                                {'ns': 0,
#                                 'pageid': 10659362,
#                                 'title': 'Yoon Dong-sik'},
#                                {'ns': 0,
#                                 'pageid': 5947126,
#                                 'title': 'Yoon Jong-hwan'},
#                                {'ns': 0,
#                                 'pageid': 36962392,
#                                 'title': 'Yoon Jung-chun'},
#                                {'ns': 0,
#                                 'pageid': 15433974,
#                                 'title': 'Yoon Kyung-shin'},
#                                {'ns': 0,
#                                 'pageid': 3562872,
#                                 'title': 'Prabda Yoon'},
#                                {'ns': 0,
#                                 'pageid': 32994317,
#                                 'title': 'Yoon Sang-hyun'},
#                                {'ns': 0,
#                                 'pageid': 55144076,
#                                 'title': 'Yoon Sung-hee'},
#                                {'ns': 0,
#                                 'pageid': 32417651,
#                                 'title': 'Yoon Yong-il'},
#                                {'ns': 0,
#                                 'pageid': 20951019,
#                                 'title': 'Tripp York'},
#                                {'ns': 0,
#                                 'pageid': 26577090,
#                                 'title': 'Megumu Yoshida'},
#                                {'ns': 0,
#                                 'pageid': 37631682,
#                                 'title': 'Naoki Yoshida'},
#                                {'ns': 0,
#                                 'pageid': 53147727,
#                                 'title': 'Takashi Yoshida (comedian)'},
#                                {'ns': 0,
#                                 'pageid': 1527527,
#                                 'title': 'Yukari Yoshihara'},
#                                {'ns': 0,
#                                 'pageid': 16422400,
#                                 'title': 'Mitsuhiro Yoshimura'},
#                                {'ns': 0,
#                                 'pageid': 4076878,
#                                 'title': 'Natsue Yoshimura'},
#                                {'ns': 0,
#                                 'pageid': 5444339,
#                                 'title': 'Christopher Yost'},
#                                {'ns': 0,
#                                 'pageid': 1459379,
#                                 'title': 'Tina Yothers'},
#                                {'ns': 0,
#                                 'pageid': 36940616,
#                                 'title': 'Yōtsukasa Dai'},
#                                {'ns': 0,
#                                 'pageid': 56463293,
#                                 'title': 'Hervé Youmbi'},
#                                {'ns': 0,
#                                 'pageid': 5865180,
#                                 'title': 'Michaël Youn'},
#                                {'ns': 0,
#                                 'pageid': 27255169,
#                                 'title': 'Ben Young (artist)'},
#                                {'ns': 0,
#                                 'pageid': 3577663,
#                                 'title': 'Brad Young (cricketer)'},
#                                {'ns': 0,
#                                 'pageid': 20232527,
#                                 'title': 'Darin Young'},
#                                {'ns': 0,
#                                 'pageid': 1570925,
#                                 'title': 'Dmitri Young'},
#                                {'ns': 0,
#                                 'pageid': 24704655,
#                                 'title': 'Jonathon Young'},
#                                {'ns': 0,
#                                 'pageid': 6182423,
#                                 'title': 'Neil Young (footballer, born 1973)'},
#                                {'ns': 0,
#                                 'pageid': 14460745,
#                                 'title': 'Paul A. Young'},
#                                {'ns': 0,
#                                 'pageid': 29740899,
#                                 'title': 'Rodney Young (American football)'},
#                                {'ns': 0,
#                                 'pageid': 10015528,
#                                 'title': 'Tim Young (baseball)'},
#                                {'ns': 0,
#                                 'pageid': 53297346,
#                                 'title': 'Willie Young (basketball)'},
#                                {'ns': 0,
#                                 'pageid': 13324315,
#                                 'title': 'Haroon Yousaf'},
#                                {'ns': 0,
#                                 'pageid': 51112437,
#                                 'title': 'Hediya Yousef'},
#                                {'ns': 0,
#                                 'pageid': 925773,
#                                 'title': 'Yordan Yovchev'},
#                                {'ns': 0, 'pageid': 28994786, 'title': 'Yu Jie'},
#                                {'ns': 0,
#                                 'pageid': 13149188,
#                                 'title': 'Yu Hongqi'},
#                                {'ns': 0,
#                                 'pageid': 57558362,
#                                 'title': 'Yu Hui-jun'},
#                                {'ns': 0,
#                                 'pageid': 24072585,
#                                 'title': 'John Yuan'},
#                                {'ns': 0,
#                                 'pageid': 42063857,
#                                 'title': 'Yuan Li'},
#                                {'ns': 0,
#                                 'pageid': 24072558,
#                                 'title': 'Matthew Yuan'},
#                                {'ns': 0,
#                                 'pageid': 20941466,
#                                 'title': 'Ron Yuan'},
#                                {'ns': 0,
#                                 'pageid': 47112476,
#                                 'title': 'Candan Yüceer'},
#                                {'ns': 0,
#                                 'pageid': 53357958,
#                                 'title': 'Deniz Yücel'},
#                                {'ns': 0,
#                                 'pageid': 2863131,
#                                 'title': 'Serap Yücesir'},
#                                {'ns': 0,
#                                 'pageid': 46852615,
#                                 'title': 'Ganna Yudkivska'},
#                                {'ns': 0,
#                                 'pageid': 15201977,
#                                 'title': 'Steve Yuhas'},
#                                {'ns': 0,
#                                 'pageid': 37309532,
#                                 'title': 'Channy Yun'},
#                                {'ns': 0,
#                                 'pageid': 53587386,
#                                 'title': 'Yun Ju-il'},
#                                {'ns': 0,
#                                 'pageid': 24740639,
#                                 'title': 'Akram Yurabayev'},
#                                {'ns': 0,
#                                 'pageid': 35033928,
#                                 'title': 'Yekaterina Yusheva'},
#                                {'ns': 0,
#                                 'pageid': 19146262,
#                                 'title': 'Antonio Zabálburu'},
#                                {'ns': 0,
#                                 'pageid': 4989414,
#                                 'title': 'Mark Zabel'},
#                                {'ns': 0,
#                                 'pageid': 3349128,
#                                 'title': 'Zulfiya Zabirova'},
#                                {'ns': 0,
#                                 'pageid': 57085049,
#                                 'title': 'Nataliia Zabolotna'},
#                                {'ns': 0,
#                                 'pageid': 5726116,
#                                 'title': 'Libor Zábranský'},
#                                {'ns': 0,
#                                 'pageid': 23442459,
#                                 'title': 'Roman Zach'},
#                                {'ns': 0,
#                                 'pageid': 26141995,
#                                 'title': 'Bill Zadick'},
#                                {'ns': 0,
#                                 'pageid': 8199607,
#                                 'title': 'Andrey Zadorozhniy'},
#                                {'ns': 0,
#                                 'pageid': 47876389,
#                                 'title': 'Saba Zafar'},
#                                {'ns': 0,
#                                 'pageid': 7327733,
#                                 'title': 'René Zagger'},
#                                {'ns': 0,
#                                 'pageid': 47569660,
#                                 'title': 'Eduard Zagumenny'},
#                                {'ns': 0,
#                                 'pageid': 24203321,
#                                 'title': 'Srgjan Zaharievski'},
#                                {'ns': 0,
#                                 'pageid': 8432810,
#                                 'title': 'Sultanah Nur Zahirah'},
#                                {'ns': 0,
#                                 'pageid': 41811268,
#                                 'title': 'S. Craig Zahler'},
#                                {'ns': 0,
#                                 'pageid': 634209,
#                                 'title': 'Christian Zahra'},
#                                {'ns': 0,
#                                 'pageid': 41511721,
#                                 'title': 'Mudar Zahran'},
#                                {'ns': 0,
#                                 'pageid': 25288141,
#                                 'title': 'Dženan Zaimović'},
#                                {'ns': 0,
#                                 'pageid': 17567237,
#                                 'title': 'Marek Zając'},
#                                {'ns': 0,
#                                 'pageid': 25701892,
#                                 'title': 'Roland Zajmi'},
#                                {'ns': 0,
#                                 'pageid': 36024847,
#                                 'title': 'Faisal Zakaria'},
#                                {'ns': 0,
#                                 'pageid': 40247886,
#                                 'title': 'Sahar Zakaria'},
#                                {'ns': 0,
#                                 'pageid': 58568391,
#                                 'title': 'Inessa Zakhareuskaya'},
#                                {'ns': 0,
#                                 'pageid': 15394612,
#                                 'title': 'Abdul Qayyum Zakir'},
#                                {'ns': 0,
#                                 'pageid': 3257376,
#                                 'title': 'Marat Zakirov'},
#                                {'ns': 0,
#                                 'pageid': 44286648,
#                                 'title': 'Dragoslava Žakula'},
#                                {'ns': 0,
#                                 'pageid': 45041418,
#                                 'title': 'Vasilios Zabelis'},
#                                {'ns': 0,
#                                 'pageid': 11252165,
#                                 'title': 'Henry Zambrano'},
#                                {'ns': 0,
#                                 'pageid': 49285655,
#                                 'title': 'Zameer Zahir'},
#                                {'ns': 0,
#                                 'pageid': 5344885,
#                                 'title': 'Katalin Zamiar'},
#                                {'ns': 0,
#                                 'pageid': 24687778,
#                                 'title': 'Gabriela Zamišková'},
#                                {'ns': 0,
#                                 'pageid': 38123478,
#                                 'title': 'Alessandro Zan'},
#                                {'ns': 0,
#                                 'pageid': 31235251,
#                                 'title': 'Néstor Zanatta'},
#                                {'ns': 0,
#                                 'pageid': 45367432,
#                                 'title': 'Enrico Zanetti'},
#                                {'ns': 0,
#                                 'pageid': 615792,
#                                 'title': 'Javier Zanetti'},
#                                {'ns': 0,
#                                 'pageid': 56808204,
#                                 'title': 'Mauro Zanetti'},
#                                {'ns': 0,
#                                 'pageid': 55843903,
#                                 'title': 'Billie Zangewa'},
#                                {'ns': 0,
#                                 'pageid': 58518936,
#                                 'title': 'Fernando Zapata'},
#                                {'ns': 0,
#                                 'pageid': 1056979,
#                                 'title': 'Javier Zapata'},
#                                {'ns': 0,
#                                 'pageid': 12552569,
#                                 'title': 'Giuseppe Zappella'},
#                                {'ns': 0,
#                                 'pageid': 11132625,
#                                 'title': 'Tuanku Zara Salim'},
#                                {'ns': 0,
#                                 'pageid': 43588248,
#                                 'title': 'Carlos Zaragoza'},
#                                {'ns': 0,
#                                 'pageid': 51211995,
#                                 'title': 'Marco Zaragoza'},
#                                {'ns': 0,
#                                 'pageid': 9331923,
#                                 'title': 'Ariel Zárate'},
#                                {'ns': 0,
#                                 'pageid': 23630163,
#                                 'title': 'Mikhail Zaritskiy'},
#                                {'ns': 0,
#                                 'pageid': 37706871,
#                                 'title': 'Reza Zarkhanli'},
#                                {'ns': 0,
#                                 'pageid': 44690040,
#                                 'title': 'Eduardo Zarzosa Sánchez'},
#                                {'ns': 0,
#                                 'pageid': 55782765,
#                                 'title': 'Ivano Zasio'},
#                                {'ns': 0,
#                                 'pageid': 58485362,
#                                 'title': 'Radek Zavadil'},
#                                {'ns': 0,
#                                 'pageid': 4090685,
#                                 'title': 'Cristina Zavalloni'},
#                                {'ns': 0,
#                                 'pageid': 5903776,
#                                 'title': 'Tomasz Zdebel'},
#                                {'ns': 0,
#                                 'pageid': 1731500,
#                                 'title': 'Victoria Zdrok'},
#                                {'ns': 0,
#                                 'pageid': 22104699,
#                                 'title': 'Clark Zealand'},
#                                {'ns': 0,
#                                 'pageid': 14659396,
#                                 'title': 'Pablo Zegarra'},
#                                {'ns': 0,
#                                 'pageid': 13001229,
#                                 'title': 'Kristoffer Zegers'},
#                                {'ns': 0,
#                                 'pageid': 10624236,
#                                 'title': 'Cyd Zeigler'},
#                                {'ns': 0,
#                                 'pageid': 5219367,
#                                 'title': 'Dusty Zeigler'},
#                                {'ns': 0,
#                                 'pageid': 52279337,
#                                 'title': 'Peter Zeihan'},
#                                {'ns': 0,
#                                 'pageid': 29246088,
#                                 'title': 'Muarem Zekir'},
#                                {'ns': 0,
#                                 'pageid': 18975299,
#                                 'title': 'Nelson Zelaya'},
#                                {'ns': 0,
#                                 'pageid': 27330945,
#                                 'title': 'Luděk Zelenka'},
#                                {'ns': 0,
#                                 'pageid': 43733002,
#                                 'title': 'Jeff Zeleny'},
#                                {'ns': 0,
#                                 'pageid': 30761324,
#                                 'title': 'Sylvia Aguilar Zéleny'},
#                                {'ns': 0,
#                                 'pageid': 11859319,
#                                 'title': 'Ray Zellars'},
#                                {'ns': 0,
#                                 'pageid': 21711505,
#                                 'title': 'Marcel Zeller'},
#                                {'ns': 0,
#                                 'pageid': 15065913,
#                                 'title': 'Marc Zellweger'},
#                                {'ns': 0,
#                                 'pageid': 870996,
#                                 'title': 'Vsevolods Zeļonijs'},
#                                {'ns': 0,
#                                 'pageid': 11524478,
#                                 'title': 'Douglas A. Zembiec'},
#                                {'ns': 0,
#                                 'pageid': 4320357,
#                                 'title': 'Roman Zentsov'},
#                                {'ns': 0,
#                                 'pageid': 6404557,
#                                 'title': 'David Zepeda'},
#                                {'ns': 0,
#                                 'pageid': 6014376,
#                                 'title': 'Luz María Zetina'},
#                                {'ns': 0,
#                                 'pageid': 19758798,
#                                 'title': 'Antonina Zetova'},
#                                {'ns': 0,
#                                 'pageid': 4566867,
#                                 'title': 'Hanna Zetterberg'},
#                                {'ns': 0,
#                                 'pageid': 22714511,
#                                 'title': 'Kristoffer Zetterstrand'},
#                                {'ns': 0, 'pageid': 58738897, 'title': 'Zezito'},
#                                {'ns': 0,
#                                 'pageid': 57719487,
#                                 'title': 'Anzela Zguna'},
#                                {'ns': 0,
#                                 'pageid': 29804085,
#                                 'title': 'Petar Zhabov'},
#                                {'ns': 0,
#                                 'pageid': 56725174,
#                                 'title': 'Zhang Jing (speed skater)'},
#                                {'ns': 0,
#                                 'pageid': 18694513,
#                                 'title': 'Zhang Bin (equestrian)'},
#                                {'ns': 0,
#                                 'pageid': 5961489,
#                                 'title': 'Zhang Enhua'},
#                                {'ns': 0,
#                                 'pageid': 35917225,
#                                 'title': 'Zhang Jingsong'},
#                                {'ns': 0,
#                                 'pageid': 6786773,
#                                 'title': 'Zhang Linli'},
#                                {'ns': 0,
#                                 'pageid': 6786837,
#                                 'title': 'Zhang Lirong'},
#                                {'ns': 0,
#                                 'pageid': 6877597,
#                                 'title': 'Zhang Rongkun'},
#                                {'ns': 0,
#                                 'pageid': 7350721,
#                                 'title': 'Xian Zhang'},
#                                {'ns': 0,
#                                 'pageid': 18755335,
#                                 'title': 'Zhang Zhiying'},
#                                {'ns': 0,
#                                 'pageid': 1345789,
#                                 'title': 'Zhao Hongbo'},
#                                {'ns': 0,
#                                 'pageid': 35726176,
#                                 'title': 'Zhao Kun'},
#                                {'ns': 0,
#                                 'pageid': 47146569,
#                                 'title': 'Sergei Zhdanov'},
#                                {'ns': 0,
#                                 'pageid': 36578899,
#                                 'title': 'Yevgeniy Zhilyayev'},
#                                {'ns': 0,
#                                 'pageid': 18174895,
#                                 'title': 'Jay Zhong'},
#                                {'ns': 0,
#                                 'pageid': 56480916,
#                                 'title': 'Stella Zhou'},
#                                {'ns': 0,
#                                 'pageid': 52619100,
#                                 'title': 'Zhi-Hua Zhou'},
#                                {'ns': 0,
#                                 'pageid': 47689892,
#                                 'title': 'Volodymyr Zhovtyak'},
#                                {'ns': 0,
#                                 'pageid': 35032439,
#                                 'title': 'Zhu Jiong'},
#                                {'ns': 0,
#                                 'pageid': 3781526,
#                                 'title': 'Thallium poisoning case of Zhu Ling'},
#                                {'ns': 0,
#                                 'pageid': 49406257,
#                                 'title': 'Zhu Xun'},
#                                {'ns': 0,
#                                 'pageid': 57597102,
#                                 'title': 'Zhuang Yi'},
#                                {'ns': 0,
#                                 'pageid': 2613758,
#                                 'title': 'Bulat Zhumadilov'},
#                                {'ns': 0,
#                                 'pageid': 3248351,
#                                 'title': 'Olena Zhupina'},
#                                {'ns': 0,
#                                 'pageid': 19028661,
#                                 'title': 'Lasha Zhvania'},
#                                {'ns': 0,
#                                 'pageid': 26257378,
#                                 'title': 'Rachid Ziar'},
#                                {'ns': 0,
#                                 'pageid': 56319063,
#                                 'title': 'Andrei Zibrov'},
#                                {'ns': 0,
#                                 'pageid': 4192958,
#                                 'title': 'Anna Carin Zidek'},
#                                {'ns': 0,
#                                 'pageid': 5600486,
#                                 'title': 'George Zidek'},
#                                {'ns': 0,
#                                 'pageid': 57872682,
#                                 'title': 'Marcus Ziegler'},
#                                {'ns': 0,
#                                 'pageid': 36026498,
#                                 'title': 'Daniel M. Ziff'},
#                                {'ns': 0,
#                                 'pageid': 6366050,
#                                 'title': 'Mark van der Zijden'},
#                                {'ns': 0,
#                                 'pageid': 48862439,
#                                 'title': 'Anca Zijlstra'},
#                                {'ns': 0,
#                                 'pageid': 55766266,
#                                 'title': 'Nina Zimmer'},
#                                {'ns': 0,
#                                 'pageid': 3536209,
#                                 'title': 'John Zimmerman (figure skater)'},
#                                {'ns': 0,
#                                 'pageid': 29561054,
#                                 'title': 'Gerald Zimmermann'},
#                                {'ns': 0,
#                                 'pageid': 48722710,
#                                 'title': 'Zdena Zimmermannová'},
#                                {'ns': 0,
#                                 'pageid': 20569460,
#                                 'title': 'Adam Zindani'},
#                                {'ns': 0,
#                                 'pageid': 25839516,
#                                 'title': 'Silvan Zingg'},
#                                {'ns': 0,
#                                 'pageid': 14170941,
#                                 'title': 'Naor Zion'},
#                                {'ns': 0,
#                                 'pageid': 58400018,
#                                 'title': 'Zita Pataki'},
#                                {'ns': 0,
#                                 'pageid': 7906495,
#                                 'title': 'Malika Zitouni'},
#                                {'ns': 0,
#                                 'pageid': 56217231,
#                                 'title': 'Maja Živec-Škulj'},
#                                {'ns': 0,
#                                 'pageid': 27419932,
#                                 'title': 'Marjan Živković'},
#                                {'ns': 0,
#                                 'pageid': 9017658,
#                                 'title': 'Mihails Ziziļevs'},
#                                {'ns': 0,
#                                 'pageid': 37501827,
#                                 'title': 'Cătălin Zmărăndescu'},
#                                {'ns': 0,
#                                 'pageid': 49269185,
#                                 'title': 'Henri Zogaib'},
#                                {'ns': 0,
#                                 'pageid': 974751,
#                                 'title': 'Ethan Zohn'},
#                                {'ns': 0,
#                                 'pageid': 15177703,
#                                 'title': 'Tirdad Zolghadr'},
#                                {'ns': 0,
#                                 'pageid': 57262916,
#                                 'title': 'Zachary Zoller'},
#                                {'ns': 0,
#                                 'pageid': 2276321,
#                                 'title': 'Perizaad Zorabian'},
#                                {'ns': 0,
#                                 'pageid': 11414865,
#                                 'title': 'Alexander Zorich'},
#                                {'ns': 0,
#                                 'pageid': 41187874,
#                                 'title': 'Guy Zu-Aretz'},
#                                {'ns': 0,
#                                 'pageid': 6298732,
#                                 'title': 'Viktor Zubarev'},
#                                {'ns': 0,
#                                 'pageid': 47784502,
#                                 'title': 'Christian Zübert'},
#                                {'ns': 0,
#                                 'pageid': 52442096,
#                                 'title': 'Ivan Zubkov'},
#                                {'ns': 0,
#                                 'pageid': 7226227,
#                                 'title': 'Olena Zubrilova'},
#                                {'ns': 0,
#                                 'pageid': 2944965,
#                                 'title': 'Abdullah Zubromawi'},
#                                {'ns': 0,
#                                 'pageid': 51545848,
#                                 'title': 'Eli Zuckerman'},
#                                {'ns': 0,
#                                 'pageid': 4005400,
#                                 'title': 'Eurelijus Žukauskas'},
#                                {'ns': 0,
#                                 'pageid': 19185301,
#                                 'title': 'Zulkarnaen Zainal'},
#                                {'ns': 0,
#                                 'pageid': 17230867,
#                                 'title': 'Vaidas Žutautas'},
#                                {'ns': 0,
#                                 'pageid': 9560273,
#                                 'title': 'Bert Zuurman'},
#                                {'ns': 0,
#                                 'pageid': 26720466,
#                                 'title': 'Wodage Zvadya'},
#                                {'ns': 0,
#                                 'pageid': 17230043,
#                                 'title': 'Rimantas Žvingilas'},
#                                {'ns': 0,
#                                 'pageid': 7378817,
#                                 'title': 'Arthur Zwane'},
#                                {'ns': 0,
#                                 'pageid': 18952615,
#                                 'title': 'Mandla Zwane'},
#                                {'ns': 0,
#                                 'pageid': 20685143,
#                                 'title': 'Clint Zweifel'},
#                                {'ns': 0,
#                                 'pageid': 12360698,
#                                 'title': 'Claudia Zwiers'},
#                                {'ns': 0,
#                                 'pageid': 10152288,
#                                 'title': 'Serge Zwikker'},
#                                {'ns': 0,
#                                 'pageid': 6872182,
#                                 'title': 'Noam Zylberman'},
#                                {'ns': 6,
#                                 'pageid': 55967923,
#                                 'title': 'File:SteveCorino2012Cropped.png'}]}}

# %% [markdown]
# ---
#
# Let's talk through the above code.
#
# ---
#
# To see what's going on, I'll print the first 10 names and the last 10 names.

# %%
print(names[:10])
print(names[-10:])
# Out:
# ['A-do', 'Jacob Aagaard', 'Aamani', 'Hallvard Aamlid', 'Jason Aaron', 'Ann Kristin Aarønes', 'John-Ragnar Aarset', 'Dagfinn Aarskog (bobsleigh)', 'Eileen Abad', 'Aydo Abay']
# ['Bert Zuurman', 'Wodage Zvadya', 'Rimantas Žvingilas', 'Arthur Zwane', 'Mandla Zwane', 'Clint Zweifel', 'Claudia Zwiers', 'Serge Zwikker', 'Noam Zylberman', 'File:SteveCorino2012Cropped.png']

# %% [markdown]
# The below code does some parsing of the names.

# %%
from collections import Counter

types = []

for name in names :
    if "(" in name :
        parts = name.split("(")
        #break
        types.append(parts[1].replace(")",""))

        
c = Counter(types)
c.most_common(10)
# Out:
# [('footballer', 106),
#  ('footballer, born 1973', 81),
#  ('musician', 56),
#  ('American football', 53),
#  ('politician', 45),
#  ('cricketer', 39),
#  ('actor', 38),
#  ('baseball', 35),
#  ('basketball', 32),
#  ('ice hockey', 26)]

# %%
parts
# Out:
# ['Dagfinn Aarskog ', 'bobsleigh)']

# %%
from collections import Counter

c = Counter([name.split()[0] for name in names])
c.most_common(10)
# Out:
# [('David', 119),
#  ('Mark', 94),
#  ('Chris', 94),
#  ('John', 83),
#  ('Paul', 83),
#  ('Jason', 79),
#  ('Michael', 70),
#  ('Peter', 63),
#  ('Brian', 56),
#  ('Mike', 53)]

# %%
len(names)
# Out:
# 12277

# %% [markdown]
# Now your turn. Pick a year, pull all the names for people born in that year, and count up the most common first names and last names.

# %%
from random import choice


choice(names)
# Out:
# 'Axel Lawarée'

# %%
# Your code here.

# %% [markdown]
# Last year we had an interesting discussion about Wikipedia fame. Are younger people more likely to be "Wikipedia Famous" (i.e., *on* Wikipedia)? Why might this be true? Why might it be false?
#
# In order to answer this question, it'd be good to have a list of everyone on Wikipedia born in the last 100 or 150 years. If you get here with some extra time, write some code to do this. Your code should define a starting year and then pull everyone born in that year on Wikipedia. Write out this data to a file, keeping track of the year the person was born in.
#
# Which year did you get with the maximum number of people?
